# %% [markdown]
# # Jupyter notebook_Carlos
# Notebook para análise de dados (Atividade 1)

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\comut\Downloads\default_of_credit_card_clients__courseware_version_1_21_19.xls')

# %%
df
# Out:
#                   ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0      798fc410-45c1      20000    2          2         1   24     2      2
# 1      8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2      85698822-43f5      90000    2          2         2   34     0      0
# 3      0737c11b-be42      50000    2          2         1   37     0      0
# 4      3b7f77cc-dbc0      50000    1          2         1   57    -1      0
# ...              ...        ...  ...        ...       ...  ...   ...    ...
# 29995  ecff42d0-bdc6     220000    1          3         1   39     0      0
# 29996  99d1fa0e-222b     150000    1          3         2   43    -1     -1
# 29997  95cdd3e7-4f24      30000    1          2         2   37     4      3
# 29998  00d03f02-04cd      80000    1          3         1   41     1     -1
# 29999  15d69f9f-5ad3      50000    1          2         1   46     0      0
#
# ...

# %% [markdown]
# # 1 e 2: Comando para análise de linhas e colunas:

# %%
df.shape
# Out:
# (30000, 25)

# %% [markdown]
# Existem 30000 linhas e 25 colunas

# %% [markdown]
# # 3: Comando para determinar e quantificar as características existentes:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  object
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_1                       30000 non-null  object
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %% [markdown]
# Existem 23 colunas numéricas (int64) e 2 categóricas (object)

# %% [markdown]
# # 4: Comando para determinar a aparência dos dados segundo as características:

# %%
df.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    165760.989333      1.586500      1.833333      1.535900     35.108800
# std     130158.590432      0.513348      0.807699      0.542698      9.851592
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_2         PAY_3         PAY_4         PAY_5         PAY_6  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.132867     -0.164333     -0.219300     -0.263900     -0.288033
# ...

# %% [markdown]
# Tendo em vista o resultado obtido com o comando acima, é possível observar uma idade média de 35 anos, variando de 0 a 79 anos, onde a maior parte dos clientes possuem de 28 a 41 anos, além disso, o limite de crédito apresenta uma média de 165 mil, variando de 0 a 1000000 para alguns clientes. Ademais, características como escolaridade, estado civil e sexo são representadas numericamente, o que indica que se tratam de variáveis categóricas codificadas, além disso, as variáveis de pagamento (PAY_2 a PAY_6) mostram que, embora a média seja levemente negativa (indicando pagamentos em dia), o intervalo de -2 a 8 revela uma variabilidade nos comportamentos, desde créditos antecipados até atrasos mais graves, outrossim, é possivel observar que a coluna PAY_1 não foi possivel ser análisada devido ao possivel uso de dados não númericos, dificultando a análise final, por fim, pode-se observar que o valor da fatura apresenta-se em média de 42 mil, além de ser possivel observar valores negativos, abrindo a possibilidade de ajustes de crédito ou inconsistencia de dados.

# %% [markdown]
# # 5: Comando para analisar se existem dados faltantes:

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_1                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# Por todas as colunas terem resultado igual a "0", indica que não existem dados faltantes, porém, durante a análise de determinação e quantificação de características, foi possivel observar que a colunas "PAY_1" é a única das colunas de pagamento na qual é caracterizada como "object", assim, sendo necessário confirmar se algum dado faltante não está conseguindo ser análisado devido a estar inserido como string

# %%
df['PAY_1'].value_counts()
# Out:
# PAY_1
# 0                13402
# -1                5047
# 1                 3261
# Not available     3021
# -2                2476
# 2                 2378
# 3                  292
# 4                   63
# 5                   23
# 8                   17
# 6                   11
# 7                    9
# Name: count, dtype: int64

# %% [markdown]
# É possivel observar que existem 3012 linhas descritas como "Not Available", assim, ao invés de estarem vazios, esses dados faltantes são registrados como texto, gerando um "falso" resultado na avaliação de dados faltantes
